# %% [markdown]
# ### Eda de datos de índice SP500

# %%
# !pip install yfinance

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# Crea un objeto Ticker de yfinance con el símbolo de la lista índice S&P500
sp500 = yf.Ticker("^GSPC")

# %%
# método history del objeto Ticker para obtener los datos históricos del símbolo posterior al año 2000
sp500_data = sp500.history(start="2000-01-01")

# %%
# Visualizacion inicial de los primeros registros
sp500_data.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-01-03 00:00:00-05:00  1469.250000  1478.000000  1438.359985  1455.219971
# 2000-01-04 00:00:00-05:00  1455.219971  1455.219971  1397.430054  1399.420044
# 2000-01-05 00:00:00-05:00  1399.420044  1413.270020  1377.680054  1402.109985
# 2000-01-06 00:00:00-05:00  1402.109985  1411.900024  1392.099976  1403.449951
# 2000-01-07 00:00:00-05:00  1403.449951  1441.469971  1400.729980  1441.469971
#
#                                Volume  Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-05:00   931800000        0.0           0.0
# 2000-01-04 00:00:00-05:00  1009000000        0.0           0.0
# 2000-01-05 00:00:00-05:00  1085500000        0.0           0.0
# 2000-01-06 00:00:00-05:00  1092300000        0.0           0.0
# 2000-01-07 00:00:00-05:00  1225200000        0.0           0.0

# %%
sp500_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5842 entries, 2000-01-03 00:00:00-05:00 to 2023-03-22 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          5842 non-null   float64
#  1   High          5842 non-null   float64
#  2   Low           5842 non-null   float64
#  3   Close         5842 non-null   float64
#  4   Volume        5842 non-null   int64
#  5   Dividends     5842 non-null   float64
#  6   Stock Splits  5842 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 365.1 KB

# %%
sp500_data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5842.000000  5842.000000  5842.000000  5842.000000  5.842000e+03
# mean   1893.588253  1904.940315  1881.291175  1893.796164  3.308349e+09
# std     982.590332   987.798712   976.929932   982.700409  1.525401e+09
# min     679.280029   695.270020   666.789978   676.530029  3.560700e+08
# 25%    1185.040039  1192.212463  1177.767487  1185.087555  1.992492e+09
# 50%    1436.885010  1446.465027  1428.264954  1437.354980  3.414400e+09
# 75%    2408.292542  2418.202454  2393.909912  2408.139893  4.164038e+09
# max    4804.509766  4818.620117  4780.040039  4796.560059  1.145623e+10
#
#        Dividends  Stock Splits
# count     5842.0        5842.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
# función pairplot de seaborn para visualizar la relación entre las variables numéricas del conjunto de dato
sns.pairplot(sp500_data)
plt.show()

# %% [markdown]
# La función pairplot crea un gráfico de dispersión para cada par de variables numéricas del conjunto de datos, y un histograma para cada variable numérica en la diagonal

# %%
# función heatmap de seaborn para visualizar la matriz de correlación entre las variables numéricas del conjunto de datos
corr = sp500_data.corr()
sns.heatmap(corr, cmap="YlGnBu")
plt.show()

# %% [markdown]
# La función heatmap crea un mapa de calor que muestra la matriz de correlación entre las variables numéricas del conjunto de datos

# %%
# función lineplot de seaborn para visualizar la serie temporal de precios de cierre
sns.lineplot(x="Date", y="Close", data=sp500_data)
plt.show()

# %% [markdown]
# La función lineplot crea un gráfico de líneas que muestra la serie temporal de precios de cierre. El argumento x es la columna que contiene las fechas, el argumento y es la columna que contiene los precios de cierre y el argumento data es el conjunto de datos

# %% [markdown]
# ### Graficar outliers y patrones en los datos

# %%
# Gráfico de diagrama de caja para el precio de cierre
sns.boxplot(x=sp500_data["Close"])
plt.show()

# %% [markdown]
# Graficar con diagramas de caja para el precio de cierre de la lista índice S&P500 posterior al año 2000.

# %%
# Gráfico de dispersión para el precio de cierre y el volumen
sns.scatterplot(x=sp500_data["Close"], y=sp500_data["Volume"])
plt.show()

# %% [markdown]
# El gráfico de dispersión indica la relación entre el precio de cierre y el volumen
